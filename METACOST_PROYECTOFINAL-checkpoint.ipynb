# %% [markdown]
# # CSV

# %%
import pandas as pd
url='https://raw.githubusercontent.com/miguelnunez21/AA_dementia/main/ProyectoFinal.csv'



# Leer el dataset desde el archivo CSV
dem = pd.read_csv(url,delimiter=';')
dem.describe(include = 'all')
# Out:
#             smoking          age  gender  educationyears           EF  \
# count   2190.000000  2190.000000    2190     2190.000000  2190.000000
# unique          NaN          NaN       2             NaN          NaN
# top             NaN          NaN  female             NaN          NaN
# freq            NaN          NaN    1112             NaN          NaN
# mean       0.672146    67.147183     NaN       10.956849    -0.193582
# std        0.708430     9.062234     NaN        3.028129     0.801368
# min        0.000000    38.000000     NaN        1.000000    -5.200000
# 25%        0.000000    61.000000     NaN        9.000000    -0.610000
# 50%        1.000000    68.000000     NaN       10.000000    -0.070000
# 75%        1.000000    74.000000     NaN       13.000000     0.390000
# max        2.000000    90.000000     NaN       24.000000     2.350000
#
#                  PS       Global     diabetes hypertension  \
# count   2190.000000  2190.000000  2190.000000         2190
# ...

# %%
from sklearn.preprocessing import StandardScaler

# Mostrar estadísticas antes de la estandarización
print("Estadísticas antes de la estandarización:")
print(dem.describe())

# Crear un objeto StandardScaler
scaler = StandardScaler()

# Copiar el DataFrame original
dem_standardized = dem.copy()

# Seleccionar todas las columnas numéricas para estandarizar
columns_to_standardize = dem_standardized.select_dtypes(include=['float64', 'int64']).columns

# Ajustar el scaler a las columnas seleccionadas y transformar los datos
# luego reemplazar las columnas originales con las estandarizadas
dem_standardized[columns_to_standardize] = scaler.fit_transform(dem_standardized[columns_to_standardize])

# Mostrar estadísticas después de la estandarización
print("\nEstadísticas después de la estandarización:")
print(dem_standardized.describe())
# Out:
# Estadísticas antes de la estandarización:
#            smoking          age  educationyears           EF           PS  \
# count  2190.000000  2190.000000     2190.000000  2190.000000  2190.000000
# mean      0.672146    67.147183       10.956849    -0.193582    -0.222350
# std       0.708430     9.062234        3.028129     0.801368     0.871702
# min       0.000000    38.000000        1.000000    -5.200000    -2.680000
# 25%       0.000000    61.000000        9.000000    -0.610000    -0.806667
# 50%       1.000000    68.000000       10.000000    -0.070000    -0.242508
# 75%       1.000000    74.000000       13.000000     0.390000     0.400000
# max       2.000000    90.000000       24.000000     2.350000     2.730000
#
#             Global     diabetes      Fazekas    lac_count  dementia_all
# count  2190.000000  2190.000000  2190.000000  2190.000000   2190.000000
# mean     -0.139076     0.145662     1.394521     0.587215      0.211872
# ...

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler


# Crear un objeto StandardScaler
scaler = StandardScaler()

# Copiar el DataFrame original
dem_standardized = dem.copy()

# Seleccionar todas las columnas numéricas para estandarizar
columns_to_standardize = dem_standardized.select_dtypes(include=['float64', 'int64']).columns

# Ajustar el scaler a las columnas seleccionadas y transformar los datos
# luego reemplazar las columnas originales con las estandarizadas
dem_standardized[columns_to_standardize] = scaler.fit_transform(dem_standardized[columns_to_standardize])


# Cambiar la configuración de pandas para mostrar todas las filas y columnas
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Mostrar todos los valores del DataFrame original y estandarizado
print("\nValores del DataFrame original:")
print(dem)

print("\nValores del DataFrame estandarizado:")
print(dem_standardized)

# Restaurar la configuración original de pandas para evitar problemas de rendimiento
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
# Out:
# Valores del DataFrame original:
#       smoking        age  gender  educationyears        EF        PS  \
# 0           1  76.596851  female             8.0 -0.619906 -0.803036
# 1           1  76.596851  female             8.0 -0.619906 -0.803036
# 2           1  76.596851  female             8.0 -0.619906 -0.803036
# 3           1  76.596851  female             8.0 -0.619906 -0.803036
# 4           1  76.202601    male            10.0 -0.476078 -0.712535
# 5           1  76.202601    male            10.0 -0.476078 -0.712535
# 6           1  76.202601    male            10.0 -0.476078 -0.712535
# 7           1  76.202601    male            10.0 -0.476078 -0.712535
# 8           1  76.202601    male            10.0 -0.476078 -0.712535
# 9           1  76.202601    male            10.0 -0.476078 -0.712535
# 10          1  76.202601    male            10.0 -0.476078 -0.712535
# 11          1  76.202601    male            10.0 -0.476078 -0.712535
# ...

# %%
import pandas as pd 
from sklearn.preprocessing import OneHotEncoder, PolynomialFeatures
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Crear un OneHotEncoder para la columna 'dementia_all'
onehot_encoder = OneHotEncoder(drop='first', sparse_output=False)

# Aplicar One-Hot Encoding a la columna 'dementia_all'
dementia_encoded = onehot_encoder.fit_transform(dem_standardized[['dementia_all']])

# Convertir a DataFrame para facilitar la visualización
dementia_encoded_df = pd.DataFrame(dementia_encoded, columns=onehot_encoder.get_feature_names_out(['dementia_all']))

# Crear un PolynomialFeatures
poly = PolynomialFeatures(degree=2, include_bias=False)

# Aplicar expansión polinómica
dementia_poly = poly.fit_transform(dementia_encoded_df)

# Convertir a DataFrame para facilitar la visualización
dementia_poly_df = pd.DataFrame(dementia_poly, columns=poly.get_feature_names_out(onehot_encoder.get_feature_names_out(['dementia_all'])))
# Tomar solo una de las nuevas columnas como la columna 'dementia_all' 
dementia_poly_df_single = dementia_poly_df.iloc[:, 0] # Usamos la primera columna

# Añadir la nueva columna 'dementia_all' al DataFrame original 
dem_standardized['dementia_all'] = dementia_poly_df_single

print (dem_standardized)





dem_standardized_encoded = pd.get_dummies(dem_standardized, drop_first=True)
print (dem_standardized_encoded)
# Out:
#        smoking       age  gender  educationyears        EF        PS  \
# 0     0.462895  1.042991  female       -0.976684 -0.532116 -0.666304
# 1     0.462895  1.042991  female       -0.976684 -0.532116 -0.666304
# 2     0.462895  1.042991  female       -0.976684 -0.532116 -0.666304
# 3     0.462895  1.042991  female       -0.976684 -0.532116 -0.666304
# 4     0.462895  0.999476    male       -0.316059 -0.352597 -0.562459
# ...        ...       ...     ...             ...       ...       ...
# 2185 -0.948999 -0.016245  female        0.674878  0.116805  0.232185
# 2186 -0.948999  0.425248  female        0.674878 -0.220196 -0.961155
# 2187  0.462895 -1.340724    male       -0.316059  0.815770  1.356679
# 2188  0.462895 -1.451098    male       -0.316059  0.478769  0.289557
# 2189  0.462895  0.094128  female       -0.316059  0.878177 -0.353011
#
#         Global  diabetes hypertension hypercholesterolemia   Fazekas  \
# ...

# %%
# Just run this code to loas the MetaCost classifier in the environment

import pandas as pd
import numpy as np
from sklearn.base import clone

class MetaCost(object):

    """A procedure for making error-based classifiers cost-sensitive

    >>> from sklearn.datasets import load_iris
    >>> from sklearn.linear_model import LogisticRegression
    >>> import pandas as pd
    >>> import numpy as np
    >>> S = pd.DataFrame(load_iris().data)
    >>> S['target'] = load_iris().target
    >>> LR = LogisticRegression(solver='lbfgs', multi_class='multinomial')
    >>> C = np.array([[0, 1, 1], [1, 0, 1], [1, 1, 0]])
    >>> model = MetaCost(S, LR, C).fit('target', 3)
    >>> model.predict_proba(load_iris().data[[2]])
    >>> model.score(S[[0, 1, 2, 3]].values, S['target'])

    .. note:: The form of the cost matrix C must be as follows:
    +---------------+----------+----------+----------+
    |  actual class |          |          |          |
    +               |          |          |          |
    |   +           | y(x)=j_1 | y(x)=j_2 | y(x)=j_3 |
    |       +       |          |          |          |
    |           +   |          |          |          |
    |predicted class|          |          |          |
    +---------------+----------+----------+----------+
    |   h(x)=j_1    |    0     |    a     |     b    |
    |   h(x)=j_2    |    c     |    0     |     d    |
    |   h(x)=j_3    |    e     |    f     |     0    |
    +---------------+----------+----------+----------+
    | C = np.array([[0, a, b],[c, 0 , d],[e, f, 0]]) |
    +------------------------------------------------+
    """
    def __init__(self, S, L, C, m=50, n=1, p=True, q=True):
        """
        :param S: The training set
        :param L: A classification learning algorithm
        :param C: A cost matrix
        :param q: Is True iff all resamples are to be used  for each examples
        :param m: The number of resamples to generate
        :param n: The number of examples in each resample
        :param p: Is True iff L produces class probabilities
        """
        if not isinstance(S, pd.DataFrame):
            raise ValueError('S must be a DataFrame object')
        new_index = list(range(len(S)))
        S.index = new_index
        self.S = S
        self.L = L
        self.C = C
        self.m = m
        self.n = len(S) * n
        self.p = p
        self.q = q

    def fit(self, flag, num_class):
        """
        :param flag: The name of classification labels
        :param num_class: The number of classes
        :return: Classifier
        """
        col = [col for col in self.S.columns if col != flag]
        S_ = {}
        M = []

        for i in range(self.m):
            # Let S_[i] be a resample of S with self.n examples
            S_[i] = self.S.sample(n=self.n, replace=True)

            X = S_[i][col].values
            y = S_[i][flag].values

            # Let M[i] = model produced by applying L to S_[i]
            model = clone(self.L)
            M.append(model.fit(X, y))

        label = []
        S_array = self.S[col].values
        for i in range(len(self.S)):
            if not self.q:
                k_th = [k for k, v in S_.items() if i not in v.index]
                M_ = list(np.array(M)[k_th])
            else:
                M_ = M

            if self.p:
                P_j = [model.predict_proba(S_array[[i]]) for model in M_]
            else:
                P_j = []
                vector = [0] * num_class
                for model in M_:
                    vector[model.predict(S_array[[i]])] = 1
                    P_j.append(vector)

            # Calculate P(j|x)
            P = np.array(np.mean(P_j, 0)).T

            # Relabel
            label.append(np.argmin(self.C.dot(P)))

        # Model produced by applying L to S with relabeled y
        X_train = self.S[col].values
        y_train = np.array(label)
        model_new = clone(self.L)
        model_new.fit(X_train, y_train)

        return model_new

# %% [markdown]
# # KNN METACOST

# %%
import numpy as np 
import pandas as pd 
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.model_selection import train_test_split, KFold, cross_val_score, StratifiedKFold
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay 
import matplotlib.pyplot as plt

# Separar características y etiquetas
X = dem_standardized_encoded.drop('dementia_all', axis=1)
y = dem_standardized_encoded['dementia_all']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# Create KNN classifier
knn = KNeighborsClassifier(n_neighbors=4)  # You can adjust n_neighbors
cv_scores = cross_val_score(knn, X_train, y_train, cv=10, scoring='accuracy')
std_deviation = np.std(cv_scores)
# Train the classifier
knn.fit(X_train, y_train)


# Make predictions on the test set
y_pred = knn.predict(X_test)

# Calculate the accuracy
accuracy = accuracy_score(y_test, y_pred)
# Calculate the confusion matrix
confusion_mat = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(confusion_mat)

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=confusion_mat,
                              display_labels=knn.classes_)
disp.plot()
plt.show()
# Out:
# Confusion Matrix:
# [[623  62]
#  [ 88 103]]

# %% [markdown]
# # 1

# %%
# Define the cost matrix
cost_matrix = np.array([[0,1], [1, 0]])

# Combine X_train and y_train into a single DataFrame
# MetaCost needs all the data to be arranged in a DataFrame
train_df = pd.DataFrame(data=X_train)
train_df['Outcome'] = pd.array(y_train)

# Create a MetaCost object with a DecisionTreeClassifier
metacost_model = MetaCost(train_df,KNeighborsClassifier(n_neighbors=4), cost_matrix)
cv_scores = cross_val_score(knn, X_train, y_train, cv=10, scoring='accuracy')
std_deviation = np.std(cv_scores)
# Fit the model to the training data.
# We need to indicate the colum of the class ('Outcome') and the number of classes (2)
model = metacost_model.fit('Outcome', 2)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
# Calculate the confusion matrix
confusion_mat = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(confusion_mat)
cost = np.sum(confusion_mat * np.transpose(cost_matrix))
cost_per_instance = cost / len(y_test)



skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
cost_scores = [] 
for train_index, test_index in skf.split(X_train, y_train):
    X_train_fold, X_val_fold = X_train.iloc[train_index], X_train.iloc[test_index]
    y_train_fold, y_val_fold = y_train.iloc[train_index], y_train.iloc[test_index] 
    # Crear y ajustar el modelo MetaCost para este pliegue
    train_df_fold = pd.DataFrame(data=X_train_fold)
    train_df_fold['Outcome'] = y_train_fold 
    metacost_model = MetaCost(train_df_fold, KNeighborsClassifier(n_neighbors=4), cost_matrix) 
    model = metacost_model.fit('Outcome', 2) 
    # Hacer predicciones en el conjunto de validación para este pliegue
    y_pred_fold = model.predict(X_val_fold)
    # Calcular la matriz de confusión y el costo para este pliegue 
    confusion_mat_fold = confusion_matrix(y_val_fold, y_pred_fold) 
    cost_fold = np.sum(confusion_mat_fold * np.transpose(cost_matrix)) 
    cost_per_instance_fold = cost_fold / len(y_val_fold) 
    cost_scores.append(cost_per_instance_fold) 
    # Calcular la desviación estándar del costo por instancia 
std_cost_per_instance = np.std(cost_scores)
# Print the cost
# Imprimir la precisión media y la desviación estándar 
print(f"Average Accuracy (cross-validation): {accuracy*100:.2f}% ± {std_deviation*100:.2f}%") 
# Imprimir el costo y el costo por instancia
print(f"Cost per instance: {cost_per_instance:.2f} ± {std_cost_per_instance:.6f}")
# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=confusion_mat,
                              display_labels=knn.classes_)
disp.plot()
plt.show()
# Out:
# C:\Users\migue\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# Confusion Matrix:
# [[609  76]
#  [ 80 111]]
# C:\Users\migue\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\migue\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\migue\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\migue\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# ...

# %% [markdown]
# # 5

# %%
# Define the cost matrix
cost_matrix = np.array([[0, 5], [1, 0]])

# Combine X_train and y_train into a single DataFrame
# MetaCost needs all the data to be arranged in a DataFrame
train_df = pd.DataFrame(data=X_train)
train_df['Outcome'] = pd.array(y_train)

# Create a MetaCost object with a DecisionTreeClassifier
metacost_model = MetaCost(train_df,KNeighborsClassifier(n_neighbors=4), cost_matrix)
cv_scores = cross_val_score(knn, X_train, y_train, cv=10, scoring='accuracy')
std_deviation = np.std(cv_scores)
# Fit the model to the training data.
# We need to indicate the colum of the class ('Outcome') and the number of classes (2)
model = metacost_model.fit('Outcome', 2)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
# Calculate the confusion matrix
confusion_mat = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(confusion_mat)
cost = np.sum(confusion_mat * np.transpose(cost_matrix))
cost_per_instance = cost / len(y_test)

# Calcular la desviación estándar del costo por instancia
cost_scores = [np.sum(confusion_matrix(y_test, model.predict(X_test)) * np.transpose(cost_matrix)) / len(y_test)] 
std_cost_per_instance = np.std(cost_scores)
# Print the cost
# Imprimir la precisión media y la desviación estándar 
print(f"Average Accuracy (cross-validation): {accuracy*100:.2f}% ± {std_deviation*100:.2f}%") 
# Imprimir el costo y el costo por instancia
print(f"Cost per instance: {cost_per_instance:.2f} ± {std_cost_per_instance:.6f}")
# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=confusion_mat,
                              display_labels=knn.classes_)
disp.plot()
plt.show()
# Out:
# Confusion Matrix:
# [[550 135]
#  [ 38 153]]
# Average Accuracy (cross-validation): 80.25% ± 2.77%
# Cost per instance: 0.37 ± 0.000000
# C:\Users\migue\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\migue\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(

# %%
print(confusion_mat)

# Calculate the cost of the classifier
cost = np.sum(confusion_mat * np.transpose(cost_matrix))

# Print the cost
print("Cost:", cost)
# Print the cost per instance
print("Cost per instance:", cost/len(y_test))
# Out:
# [[550 135]
#  [ 38 153]]
# Cost: 325
# Cost per instance: 0.3710045662100457

# %% [markdown]
# # 10

# %%
# Define the cost matrix
cost_matrix = np.array([[0, 10], [1, 0]])

# Combine X_train and y_train into a single DataFrame
# MetaCost needs all the data to be arranged in a DataFrame
train_df = pd.DataFrame(data=X_train)
train_df['Outcome'] = pd.array(y_train)

# Create a MetaCost object with a DecisionTreeClassifier
metacost_model = MetaCost(train_df,KNeighborsClassifier(n_neighbors=4), cost_matrix)
cv_scores = cross_val_score(knn, X_train, y_train, cv=10, scoring='accuracy')
std_deviation = np.std(cv_scores)
# Fit the model to the training data.
# We need to indicate the colum of the class ('Outcome') and the number of classes (2)
model = metacost_model.fit('Outcome', 2)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
# Calculate the confusion matrix
confusion_mat = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(confusion_mat)
cost = np.sum(confusion_mat * np.transpose(cost_matrix))
cost_per_instance = cost / len(y_test)

# Calcular la desviación estándar del costo por instancia
cost_scores = [np.sum(confusion_matrix(y_test, model.predict(X_test)) * np.transpose(cost_matrix)) / len(y_test)] 
std_cost_per_instance = np.std(cost_scores)
# Print the cost
# Imprimir la precisión media y la desviación estándar 
print(f"Average Accuracy (cross-validation): {accuracy*100:.2f}% ± {std_deviation*100:.2f}%") 
# Imprimir el costo y el costo por instancia
print(f"Cost per instance: {cost_per_instance:.2f} ± {std_cost_per_instance:.6f}")
# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=confusion_mat,
                              display_labels=knn.classes_)
disp.plot()
plt.show()
# Out:
# Confusion Matrix:
# [[519 166]
#  [ 31 160]]
# Average Accuracy (cross-validation): 77.51% ± 2.77%
# Cost per instance: 0.54 ± 0.000000
# C:\Users\migue\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\migue\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(

# %% [markdown]
# # KNN (2) (NO)

# %%
import numpy as np 
import pandas as pd
from sklearn.model_selection import StratifiedKFold 
from sklearn.metrics import accuracy_score, confusion_matrix 
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, Input 
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.initializers import HeNormal 
from tensorflow.keras import optimizers


# Las características
X = dem_standardized_encoded.iloc[:, :-1]
# La clase
y = dem_standardized_encoded.iloc[:, -1]

# Definir el número de pliegues
n_splits = 10

# Crear un objeto StratifiedKFold
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

# Crear una lista vacía para almacenar las puntuaciones de precisión y costos para cada pliegue
accuracy_scores_all = {1: [], 5: [], 10: []}
cost_scores_all = {1: [], 5: [], 10: []}





# List of cost matrices
cost_matrices = {
    1: np.array([[0, 1], [1, 0]]),
    5: np.array([[0, 5], [1, 0]]),
    10: np.array([[0, 10], [1, 0]])
}

# Iterar a través de las matrices de costos
for cost_value, cost_matrix in cost_matrices.items():
    accuracy_scores = []
    cost_scores = []

    # Iterar a través de los pliegues
    for train_index, test_index in skf.split(X, y):
        # Dividir los datos en conjuntos de entrenamiento y validación para este pliegue
        X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[test_index]
        y_train_fold, y_val_fold = y.iloc[train_index], y.iloc[test_index]

        # Crear un DataFrame para MetaCost
        train_df_fold = pd.DataFrame(data=X_train_fold)
        train_df_fold['Outcome'] = y_train_fold

        # Crear y ajustar el modelo MetaCost para este pliegue con una red neuronal
        metacost_model = MetaCost(train_df_fold, KNeighborsClassifier(n_neighbors=4), cost_matrix)
        model=KNeighborsClassifier(n_neighbors=4)
        X_train = train_df_fold.drop(columns=['Outcome'])
        y_train = train_df_fold['Outcome'] 
        model.fit(X_train, y_train)

        # Hacer predicciones en el conjunto de validación para este pliegue
        y_pred_fold = model.predict(X_val_fold)
      
      

        # Calcular la precisión para este pliegue
        accuracy_fold = accuracy_score(y_val_fold, y_pred_fold)
        accuracy_scores.append(accuracy_fold)

        # Calcular el costo para este pliegue
        confusion_mat = confusion_matrix(y_val_fold, y_pred_fold)
        cost = np.sum(confusion_mat * np.transpose(cost_matrix))
        cost_scores.append(cost)
        print(f"Cost Matrix: {cost_value}, Fold: {len(accuracy_scores)}, Accuracy: {accuracy_fold}, Cost: {cost}")

    # Guardar los resultados para cada matriz de costos
    accuracy_scores_all[cost_value] = accuracy_scores
    cost_scores_all[cost_value] = cost_scores

# Fin del bucle de validación cruzada

# Mostrar resultados para cada matriz de costos
for cost_value in [1, 5, 10]:
    mean_accuracy = np.mean(accuracy_scores_all[cost_value])
    std_deviation = np.std(accuracy_scores_all[cost_value])
    mean_cost = np.mean(cost_scores_all[cost_value])
    std_cost = np.std(cost_scores_all[cost_value])
    divisor = len(y_val_fold)
    cost_scores_per_instance = [x / divisor for x in cost_scores_all[cost_value]]
    mean_cost_per_instance = np.mean(cost_scores_per_instance)
    std_cost_per_instance = np.std(cost_scores_per_instance)

    print(f"\nResults for Cost Matrix with cost {cost_value}:") 
    print(f"Accuracy: {mean_accuracy*100:.2f}% ± {std_deviation*100:.2f}%") 
    print(f"Cost per instance: {mean_cost_per_instance} ± {std_cost_per_instance}")

# %% [markdown]
# # NEURAL NETWORK (NO)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.callbacks import EarlyStopping

# Las características
X = dem_standardized_encoded.iloc[:, :-1]
# La clase
y = dem_standardized_encoded.iloc[:, -1]

# Definir el número de pliegues
n_splits = 10

# Crear un objeto StratifiedKFold
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

# Crear una lista vacía para almacenar las puntuaciones de precisión y costos para cada pliegue
accuracy_scores_all = {1: [], 5: [], 10: []}
cost_scores_all = {1: [], 5: [], 10: []}

# Obtener la forma de entrada
input_shape = X.shape[1]

# Función para crear el modelo
def create_model():
    model = Sequential([
        Input(shape=(input_shape,)),
        Dense(100, activation='relu'),
        Dense(100, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model



# List of cost matrices
cost_matrices = {
    1: np.array([[0, 1], [1, 0]]),
    5: np.array([[0, 5], [1, 0]]),
    10: np.array([[0, 10], [1, 0]])
}

# Iterar a través de las matrices de costos
for cost_value, cost_matrix in cost_matrices.items():
    accuracy_scores = []
    cost_scores = []

    # Iterar a través de los pliegues
    for train_index, test_index in skf.split(X, y):
        # Dividir los datos en conjuntos de entrenamiento y validación para este pliegue
        X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[test_index]
        y_train_fold, y_val_fold = y.iloc[train_index], y.iloc[test_index]

        # Crear un DataFrame para MetaCost
        train_df_fold = pd.DataFrame(data=X_train_fold)
        train_df_fold['Outcome'] = y_train_fold

        # Crear y ajustar el modelo MetaCost para este pliegue con una red neuronal
        metacost_model = MetaCost(train_df_fold, create_model(), cost_matrix)
        model=create_model()
        early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
        X_train = train_df_fold.drop(columns=['Outcome'])
        y_train = train_df_fold['Outcome'] 
        model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=0, validation_split=0.2, callbacks=[early_stopping])

        # Hacer predicciones en el conjunto de validación para este pliegue
        y_pred_fold = model.predict(X_val_fold)
        y_pred_fold = (y_pred_fold > 0.5).astype(int)
      

        # Calcular la precisión para este pliegue
        accuracy_fold = accuracy_score(y_val_fold, y_pred_fold)
        accuracy_scores.append(accuracy_fold)

        # Calcular el costo para este pliegue
        confusion_mat = confusion_matrix(y_val_fold, y_pred_fold)
        cost = np.sum(confusion_mat * np.transpose(cost_matrix))
        cost_scores.append(cost)

    # Guardar los resultados para cada matriz de costos
    accuracy_scores_all[cost_value] = accuracy_scores
    cost_scores_all[cost_value] = cost_scores

# Fin del bucle de validación cruzada

# Mostrar resultados para cada matriz de costos
for cost_value in [1, 5, 10]:
    print(f"\nResults for Cost Matrix with cost {cost_value}:")
    mean_accuracy = np.mean(accuracy_scores_all[cost_value])
    std_deviation = np.std(accuracy_scores_all[cost_value])
    mean_cost = np.mean(cost_scores_all[cost_value])
    std_cost = np.std(cost_scores_all[cost_value])
    divisor = len(y_val_fold)
    cost_scores_per_instance = [x / divisor for x in cost_scores_all[cost_value]]
    mean_cost_per_instance = np.mean(cost_scores_per_instance)
    std_cost_per_instance = np.std(cost_scores_per_instance)

    print(f"\nResults for Cost Matrix with cost {cost_value}:") 
    print(f"Accuracy: {mean_accuracy*100:.2f}% ± {std_deviation*100:.2f}%")
    print(f"Cost per instance: {mean_cost_per_instance} ± {std_cost_per_instance}")

# %% [markdown]
# # NEURAL NETWORK 2

# %% [markdown]
# # 1

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.callbacks import EarlyStopping

X = dem_standardized_encoded.iloc[:, :-1]
y = dem_standardized_encoded.iloc[:, -1]

cost_matrix = np.array([[0, 1], [1, 0]])

def create_model(input_shape):
    model = Sequential([
        Input(shape=(input_shape,)),
        Dense(100, activation='relu'),
        Dense(100, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

n_splits = 10
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

accuracy_scores = []
cost_scores = []

for train_index, test_index in skf.split(X, y):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[test_index]
    y_train_fold, y_val_fold = y.iloc[train_index], y.iloc[test_index]
    
    model = create_model(input_shape=X_train_fold.shape[1])
    early_stopping = EarlyStopping(monitor='val_loss', patience=3)
    model.fit(X_train_fold, y_train_fold, epochs=50, batch_size=32, validation_data=(X_val_fold, y_val_fold), callbacks=[early_stopping], verbose=0)
    
    y_pred_fold = model.predict(X_val_fold)
    y_pred_classes = (y_pred_fold > 0.5).astype(int)
    
    accuracy_fold = accuracy_score(y_val_fold, y_pred_classes)
    accuracy_scores.append(accuracy_fold)
    
    confusion_mat = confusion_matrix(y_val_fold, y_pred_classes)
    cost = np.sum(confusion_mat * np.transpose(cost_matrix))
    cost_scores.append(cost)

print("Precisión media:", np.mean(accuracy_scores))
print("Desviación estándar de la precisión:", np.std(accuracy_scores))
print("Costo medio:", np.mean(cost_scores))
print("Desviación estándar del costo:", np.std(cost_scores))

divisor = len(y_val_fold)
cost_scores_per_instance = [x / divisor for x in cost_scores]
print("Costo medio por instancia:", np.mean(cost_scores_per_instance))
print("Desviación estándar del costo por instancia:", np.std(cost_scores_per_instance))
print (confusion_mat)
# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=confusion_mat,
                              display_labels=[0,1])
disp.plot()
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001FCF7E56520> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# ...

# %% [markdown]
# # 5

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.callbacks import EarlyStopping

X = dem_standardized_encoded.iloc[:, :-1]
y = dem_standardized_encoded.iloc[:, -1]

cost_matrix = np.array([[0, 5], [1, 0]])

def create_model(input_shape):
    model = Sequential([
        Input(shape=(input_shape,)),
        Dense(100, activation='relu'),
        Dense(100, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

n_splits = 10
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

accuracy_scores = []
cost_scores = []

for train_index, test_index in skf.split(X, y):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[test_index]
    y_train_fold, y_val_fold = y.iloc[train_index], y.iloc[test_index]
    
    model = create_model(input_shape=X_train_fold.shape[1])
    early_stopping = EarlyStopping(monitor='val_loss', patience=3)
    model.fit(X_train_fold, y_train_fold, epochs=50, batch_size=32, validation_data=(X_val_fold, y_val_fold), callbacks=[early_stopping], verbose=0)
    
    y_pred_fold = model.predict(X_val_fold)
    y_pred_classes = (y_pred_fold > 0.5).astype(int)
    
    accuracy_fold = accuracy_score(y_val_fold, y_pred_classes)
    accuracy_scores.append(accuracy_fold)
    
    confusion_mat = confusion_matrix(y_val_fold, y_pred_classes)
    cost = np.sum(confusion_mat * np.transpose(cost_matrix))
    cost_scores.append(cost)

print("Precisión media:", np.mean(accuracy_scores))
print("Desviación estándar de la precisión:", np.std(accuracy_scores))
print("Costo medio:", np.mean(cost_scores))
print("Desviación estándar del costo:", np.std(cost_scores))

divisor = len(y_val_fold)
cost_scores_per_instance = [x / divisor for x in cost_scores]
print("Costo medio por instancia:", np.mean(cost_scores_per_instance))
print("Desviación estándar del costo por instancia:", np.std(cost_scores_per_instance))
print (confusion_mat)
# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=confusion_mat,
                              display_labels=[0,1])
disp.plot()
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Precisión media: 0.9027397260273972
# Desviación estándar de la precisión: 0.017572494433693017
# Costo medio: 91.7
# Desviación estándar del costo: 17.877639665235453
# Costo medio por instancia: 0.4187214611872146
# Desviación estándar del costo por instancia: 0.08163305783212536
# [[189   1]
#  [ 23   6]]

# %% [markdown]
# # 10

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.callbacks import EarlyStopping

X = dem_standardized_encoded.iloc[:, :-1]
y = dem_standardized_encoded.iloc[:, -1]

cost_matrix = np.array([[0, 10], [1, 0]])

def create_model(input_shape):
    model = Sequential([
        Input(shape=(input_shape,)),
        Dense(100, activation='relu'),
        Dense(100, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

n_splits = 10
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

accuracy_scores = []
cost_scores = []

for train_index, test_index in skf.split(X, y):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[test_index]
    y_train_fold, y_val_fold = y.iloc[train_index], y.iloc[test_index]
    
    model = create_model(input_shape=X_train_fold.shape[1])
    early_stopping = EarlyStopping(monitor='val_loss', patience=3)
    model.fit(X_train_fold, y_train_fold, epochs=50, batch_size=32, validation_data=(X_val_fold, y_val_fold), callbacks=[early_stopping], verbose=0)
    
    y_pred_fold = model.predict(X_val_fold)
    y_pred_classes = (y_pred_fold > 0.5).astype(int)
    
    accuracy_fold = accuracy_score(y_val_fold, y_pred_classes)
    accuracy_scores.append(accuracy_fold)
    
    confusion_mat = confusion_matrix(y_val_fold, y_pred_classes)
    cost = np.sum(confusion_mat * np.transpose(cost_matrix))
    cost_scores.append(cost)

print("Precisión media:", np.mean(accuracy_scores))
print("Desviación estándar de la precisión:", np.std(accuracy_scores))
print("Costo medio:", np.mean(cost_scores))
print("Desviación estándar del costo:", np.std(cost_scores))

divisor = len(y_val_fold)
cost_scores_per_instance = [x / divisor for x in cost_scores]
print("Costo medio por instancia:", np.mean(cost_scores_per_instance))
print("Desviación estándar del costo por instancia:", np.std(cost_scores_per_instance))
print (confusion_mat)
# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=confusion_mat,
                              display_labels=[0,1])
disp.plot()
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Precisión media: 0.8945205479452054
# Desviación estándar de la precisión: 0.016007806523249405
# Costo medio: 181.5
# Desviación estándar del costo: 32.946168214224855
# Costo medio por instancia: 0.8287671232876711
# Desviación estándar del costo por instancia: 0.15043912426586692
# [[184   6]
#  [ 21   8]]

# %% [markdown]
# # DEEP LEARNING NEURAL NETWORK (NO)

# %%
import numpy as np 
import pandas as pd
from sklearn.model_selection import StratifiedKFold 
from sklearn.metrics import accuracy_score, confusion_matrix,ConfusionMatrixDisplay
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, Input 
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.initializers import HeNormal 
from tensorflow.keras import optimizers
import matplotlib.pyplot as plt

# Las características
X = dem_standardized_encoded.iloc[:, :-1]
# La clase
y = dem_standardized_encoded.iloc[:, -1]

# Definir el número de pliegues
n_splits = 10

# Crear un objeto StratifiedKFold
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

# Crear una lista vacía para almacenar las puntuaciones de precisión y costos para cada pliegue
accuracy_scores_all = {1: [], 5: [], 10: []}
cost_scores_all = {1: [], 5: [], 10: []}

# Obtener la forma de entrada
input_shape = (X.shape[1],)

# Función para crear el modelo
def create_model():
    model = Sequential()
    model.add(Input(shape=input_shape,))
    initializer = HeNormal() 
    model.add(Dense(100, activation='relu', kernel_initializer=initializer, name='dense_0'))
    model.add(Dense(100, activation='relu', kernel_initializer=initializer, name='dense_1'))
    model.add(Dense(1, activation='sigmoid', name='dense_3')) 
    optimizer = optimizers.Adam()
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return model



# List of cost matrices
cost_matrices = {
    1: np.array([[0, 1], [1, 0]]),
    5: np.array([[0, 5], [1, 0]]),
    10: np.array([[0, 10], [1, 0]])
}

# Iterar a través de las matrices de costos
for cost_value, cost_matrix in cost_matrices.items():
    accuracy_scores = []
    cost_scores = []


    # Iterar a través de los pliegues
    for train_index, test_index in skf.split(X, y):
        # Dividir los datos en conjuntos de entrenamiento y validación para este pliegue
        X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[test_index]
        y_train_fold, y_val_fold = y.iloc[train_index], y.iloc[test_index]

        # Crear un DataFrame para MetaCost
        train_df_fold = pd.DataFrame(data=X_train_fold)
        train_df_fold['Outcome'] = y_train_fold

        # Crear y ajustar el modelo MetaCost para este pliegue con una red neuronal
        metacost_model = MetaCost(train_df_fold, create_model(), cost_matrix)
        model=create_model()
        early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
        X_train = train_df_fold.drop(columns=['Outcome'])
        y_train = train_df_fold['Outcome'] 
        model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=0, validation_split=0.2, callbacks=[early_stopping])

        # Hacer predicciones en el conjunto de validación para este pliegue
        y_pred_fold = model.predict(X_val_fold)
        y_pred_fold = (y_pred_fold > 0.5).astype(int)
      

        # Calcular la precisión para este pliegue
        accuracy_fold = accuracy_score(y_val_fold, y_pred_fold)
        accuracy_scores.append(accuracy_fold)

        # Calcular el costo para este pliegue
        confusion_mat = confusion_matrix(y_val_fold, y_pred_fold) 
        cost = np.sum(confusion_mat * np.transpose(cost_matrix))
        cost_scores.append(cost)

    # Guardar los resultados para cada matriz de costos
    accuracy_scores_all[cost_value] = accuracy_scores
    cost_scores_all[cost_value] = cost_scores
    

# Fin del bucle de validación cruzada

# Mostrar resultados para cada matriz de costos
for cost_value in [1, 5, 10]:
    mean_accuracy = np.mean(accuracy_scores_all[cost_value])
    std_deviation = np.std(accuracy_scores_all[cost_value])
    mean_cost = np.mean(cost_scores_all[cost_value])
    std_cost = np.std(cost_scores_all[cost_value])
    divisor = len(y_val_fold)
    cost_scores_per_instance = [x / divisor for x in cost_scores_all[cost_value]]
    mean_cost_per_instance = np.mean(cost_scores_per_instance)
    std_cost_per_instance = np.std(cost_scores_per_instance)

    print(f"\nResults for Cost Matrix with cost {cost_value}:") 
    print(f"Accuracy: {mean_accuracy*100:.2f}% ± {std_deviation*100:.2f}%") 
    print(f"Cost per instance: {mean_cost_per_instance} ± {std_cost_per_instance}")
    #mean_confusion_mat = np.mean(confusion_matrices, axis=0)
    disp = ConfusionMatrixDisplay(confusion_matrix=confusion_mat, display_labels=[0, 1])
    disp.plot(cmap=plt.cm.Blues)
    plt.title(f'Confusion Matrix {cost_value}')
    plt.show()

# %% [markdown]
# # deep learning neural netwrk2

# %% [markdown]
# # 1

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras import optimizers

X = dem_standardized_encoded.iloc[:, :-1]
y = dem_standardized_encoded.iloc[:, -1]

cost_matrix = np.array([[0, 1], [1, 0]])

def create_model(input_shape):
    model = Sequential()
    model.add(Input(shape=input_shape))
    initializer = HeNormal()
    model.add(Dense(100, activation='relu', kernel_initializer=initializer, name='dense_0'))
    model.add(Dense(100, activation='relu', kernel_initializer=initializer, name='dense_1'))
    model.add(Dense(1, activation='sigmoid', name='dense_3'))
    optimizer = optimizers.Adam()
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return model

n_splits = 10
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

accuracy_scores = []
cost_scores = []

for train_index, test_index in skf.split(X, y):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[test_index]
    y_train_fold, y_val_fold = y.iloc[train_index], y.iloc[test_index]
    
    model = create_model(input_shape=(X_train_fold.shape[1],))
    early_stopping = EarlyStopping(monitor='val_loss', patience=3)
    model.fit(X_train_fold, y_train_fold, epochs=50, batch_size=32, validation_data=(X_val_fold, y_val_fold), callbacks=[early_stopping], verbose=0)
    
    y_pred_fold = model.predict(X_val_fold)
    y_pred_classes = (y_pred_fold > 0.5).astype(int)
    
    accuracy_fold = accuracy_score(y_val_fold, y_pred_classes)
    accuracy_scores.append(accuracy_fold)
    
    confusion_mat = confusion_matrix(y_val_fold, y_pred_classes)
    cost = np.sum(confusion_mat * np.transpose(cost_matrix))
    cost_scores.append(cost)

print("Precisión media:", np.mean(accuracy_scores))
print("Desviación estándar de la precisión:", np.std(accuracy_scores))
print("Costo medio:", np.mean(cost_scores))
print("Desviación estándar del costo:", np.std(cost_scores))

divisor = len(y_val_fold)
cost_scores_per_instance = [x / divisor for x in cost_scores]
print("Costo medio por instancia:", np.mean(cost_scores_per_instance))
print("Desviación estándar del costo por instancia:", np.std(cost_scores_per_instance))
print (confusion_mat)
# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=confusion_mat,
                              display_labels=[0,1])
disp.plot()
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Precisión media: 0.9018264840182649
# Desviación estándar de la precisión: 0.023748682418165915
# Costo medio: 21.5
# Desviación estándar del costo: 5.200961449578338
# Costo medio por instancia: 0.09817351598173515
# Desviación estándar del costo por instancia: 0.023748682418165922
# [[189   1]
#  [ 17  12]]

# %% [markdown]
# # 5

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras import optimizers

X = dem_standardized_encoded.iloc[:, :-1]
y = dem_standardized_encoded.iloc[:, -1]

cost_matrix = np.array([[0, 5], [1, 0]])

def create_model(input_shape):
    model = Sequential()
    model.add(Input(shape=input_shape))
    initializer = HeNormal()
    model.add(Dense(100, activation='relu', kernel_initializer=initializer, name='dense_0'))
    model.add(Dense(100, activation='relu', kernel_initializer=initializer, name='dense_1'))
    model.add(Dense(1, activation='sigmoid', name='dense_3'))
    optimizer = optimizers.Adam()
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return model

n_splits = 10
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

accuracy_scores = []
cost_scores = []

for train_index, test_index in skf.split(X, y):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[test_index]
    y_train_fold, y_val_fold = y.iloc[train_index], y.iloc[test_index]
    
    model = create_model(input_shape=(X_train_fold.shape[1],))
    early_stopping = EarlyStopping(monitor='val_loss', patience=3)
    model.fit(X_train_fold, y_train_fold, epochs=50, batch_size=32, validation_data=(X_val_fold, y_val_fold), callbacks=[early_stopping], verbose=0)
    
    y_pred_fold = model.predict(X_val_fold)
    y_pred_classes = (y_pred_fold > 0.5).astype(int)
    
    accuracy_fold = accuracy_score(y_val_fold, y_pred_classes)
    accuracy_scores.append(accuracy_fold)
    
    confusion_mat = confusion_matrix(y_val_fold, y_pred_classes)
    cost = np.sum(confusion_mat * np.transpose(cost_matrix))
    cost_scores.append(cost)

print("Precisión media:", np.mean(accuracy_scores))
print("Desviación estándar de la precisión:", np.std(accuracy_scores))
print("Costo medio:", np.mean(cost_scores))
print("Desviación estándar del costo:", np.std(cost_scores))

divisor = len(y_val_fold)
cost_scores_per_instance = [x / divisor for x in cost_scores]
print("Costo medio por instancia:", np.mean(cost_scores_per_instance))
print("Desviación estándar del costo por instancia:", np.std(cost_scores_per_instance))
print (confusion_mat)
# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=confusion_mat,
                              display_labels=[0,1])
disp.plot()
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Precisión media: 0.9068493150684931
# Desviación estándar de la precisión: 0.025927067701513037
# Costo medio: 85.2
# Desviación estándar del costo: 27.24261367783936
# Costo medio por instancia: 0.38904109589041097
# Desviación estándar del costo por instancia: 0.12439549624584181
# [[182   8]
#  [ 19  10]]

# %% [markdown]
# # 10

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras import optimizers

X = dem_standardized_encoded.iloc[:, :-1]
y = dem_standardized_encoded.iloc[:, -1]

cost_matrix = np.array([[0, 10], [1, 0]])

def create_model(input_shape):
    model = Sequential()
    model.add(Input(shape=input_shape))
    initializer = HeNormal()
    model.add(Dense(100, activation='relu', kernel_initializer=initializer, name='dense_0'))
    model.add(Dense(100, activation='relu', kernel_initializer=initializer, name='dense_1'))
    model.add(Dense(1, activation='sigmoid', name='dense_3'))
    optimizer = optimizers.Adam()
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return model

n_splits = 10
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

accuracy_scores = []
cost_scores = []

for train_index, test_index in skf.split(X, y):
    X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[test_index]
    y_train_fold, y_val_fold = y.iloc[train_index], y.iloc[test_index]
    
    model = create_model(input_shape=(X_train_fold.shape[1],))
    early_stopping = EarlyStopping(monitor='val_loss', patience=3)
    model.fit(X_train_fold, y_train_fold, epochs=50, batch_size=32, validation_data=(X_val_fold, y_val_fold), callbacks=[early_stopping], verbose=0)
    
    y_pred_fold = model.predict(X_val_fold)
    y_pred_classes = (y_pred_fold > 0.5).astype(int)
    
    accuracy_fold = accuracy_score(y_val_fold, y_pred_classes)
    accuracy_scores.append(accuracy_fold)
    
    confusion_mat = confusion_matrix(y_val_fold, y_pred_classes)
    cost = np.sum(confusion_mat * np.transpose(cost_matrix))
    cost_scores.append(cost)

print("Precisión media:", np.mean(accuracy_scores))
print("Desviación estándar de la precisión:", np.std(accuracy_scores))
print("Costo medio:", np.mean(cost_scores))
print("Desviación estándar del costo:", np.std(cost_scores))

divisor = len(y_val_fold)
cost_scores_per_instance = [x / divisor for x in cost_scores]
print("Costo medio por instancia:", np.mean(cost_scores_per_instance))
print("Desviación estándar del costo por instancia:", np.std(cost_scores_per_instance))
print (confusion_mat)
# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=confusion_mat,
                              display_labels=[0,1])
disp.plot()
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Precisión media: 0.9031963470319635
# Desviación estándar de la precisión: 0.019671834911906858
# Costo medio: 172.4
# Desviación estándar del costo: 36.04774611539534
# Costo medio por instancia: 0.7872146118721461
# Desviación estándar del costo por instancia: 0.1646015804355952
# [[183   7]
#  [ 17  12]]
